# %% [markdown]
# # Procesamiento y Limpieza de los Datos

# %% [raw]
# Al no haber Missing Values y sólo duplicados se procede a eliminar los mismos dado que su representación es infima sobre los datos representando unicamente un 0.44% (en terminos abstolutos nos deja un total de filas duplicadas de 28.473 sobre un total de registros de 6.489.062).
#
# Resumiendo, únicamente se hará un procesamiento sobre la eliminación de los valores duplicados.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/jmorano/Documents/Plantillas personalizadas de Office/Coderhouse/Data Science/Modulo 2 - Data Science Fundamentos para la Ciencia de Datos II/Proyecto - Juan Martin Morano/Data/Raw/full_data_flightdelay.csv', sep=',')

# %%
df_sin_duplicados = df.drop_duplicates()

# Mostrar el DataFrame sin duplicados
print("\nDataFrame sin duplicados:")
df_sin_duplicados
# Out:
# DataFrame sin duplicados:
#          MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 0            1            7          0    0800-0859               2
# 1            1            7          0    0700-0759               7
# 2            1            7          0    0600-0659               7
# 3            1            7          0    0600-0659               9
# 4            1            7          0    0001-0559               7
# ...        ...          ...        ...          ...             ...
# 6489057     12            7          0    2300-2359               1
# 6489058     12            7          0    1800-1859               1
# 6489059     12            7          0    2000-2059               1
# 6489060     12            7          0    2100-2159               1
# 6489061     12            7          1    2100-2159               1
#
#          SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# ...

# %%
#Control de la eliminación exitosa
if (6489062 - 28473) == df_sin_duplicados.shape[0]:
    print("Eliminación con Éxito")
else: print("Revisar")
# Out:
# Eliminación con Éxito

# %%
#Control de las columnas que quedarán en el dataframe procesado
df.columns
# Out:
# Index(['MONTH', 'DAY_OF_WEEK', 'DEP_DEL15', 'DEP_TIME_BLK', 'DISTANCE_GROUP',
#        'SEGMENT_NUMBER', 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS',
#        'CARRIER_NAME', 'AIRPORT_FLIGHTS_MONTH', 'AIRLINE_FLIGHTS_MONTH',
#        'AIRLINE_AIRPORT_FLIGHTS_MONTH', 'AVG_MONTHLY_PASS_AIRPORT',
#        'AVG_MONTHLY_PASS_AIRLINE', 'FLT_ATTENDANTS_PER_PASS',
#        'GROUND_SERV_PER_PASS', 'PLANE_AGE', 'DEPARTING_AIRPORT', 'LATITUDE',
#        'LONGITUDE', 'PREVIOUS_AIRPORT', 'PRCP', 'SNOW', 'SNWD', 'TMAX',
#        'AWND'],
#       dtype='object')

# %%
df_sin_duplicados.to_csv('C:/Users/jmorano/Documents/Plantillas personalizadas de Office/Coderhouse/Data Science/Modulo 2 - Data Science Fundamentos para la Ciencia de Datos II/Proyecto - Juan Martin Morano/Data/Processed/full_data_flightdelay_processed.csv')

# %% [raw]
# A continuación se realizará la creación de una semilla, plantada en 42, para crear una muestra que se mantenga fija en caso de necesitarse para posteriores pruebas. Esta misma será guardada en la carpeta de procesados para contar con su fácil disponibilidad para lo que se necesite.

# %%
muestra_df = df.sample(6000,random_state=42)
muestra_df
# Out:
#          MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 984735       3            5          0    1500-1559               3
# 4740332      9            7          0    2200-2259               5
# 6361351     12            1          0    1900-1959               3
# 4012189      8            3          0    1700-1759               6
# 4789024      9            5          0    0800-0859               2
# ...        ...          ...        ...          ...             ...
# 970280       3            2          0    1400-1459               6
# 2722396      6            6          0    1500-1559               2
# 1665128      4            1          0    1500-1559               3
# 1202368      3            2          0    2100-2159               4
# 1595147      4            7          0    2200-2259               1
#
#          SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# 984735                4                  27               69
# ...

# %%
muestra_df.to_csv('C:/Users/jmorano/Documents/Plantillas personalizadas de Office/Coderhouse/Data Science/Modulo 2 - Data Science Fundamentos para la Ciencia de Datos II/Proyecto - Juan Martin Morano/Data/Processed/muestra_aleatoria.csv')
